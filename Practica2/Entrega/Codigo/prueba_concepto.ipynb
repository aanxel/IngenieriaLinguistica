# %% [markdown]
# ### Importar librería

# %%
import clasificacion_textos as ct

# %% [markdown]
# ### Establecer ubicaciones de directorio de datos y ficheros de compilación, partición y clasificación

# %%
import os

# Equivalente a ../Datos
dir_documentos = os.path.join(os.path.pardir, 'Datos')

# Ficheros temporales
fichero_particion = 'particion_train_test.json'
fichero_clasificacion = 'clasificacion.json'
fichero_compilacion = 'compilacion.json'

# %% [markdown]
# ### Generar una nueva partición de entrenamiento / test
#
# En este caso no se hace porque ya se ha generado una previamente.

# %%
# ct.generar_particion_train_test(
#     f_salida=fichero_particion,
#     temas=('Politica', 'Deportes', 'Salud'),
#     dir_docs=dir_documentos,
#     prop_train=0.5
# )

# %% [markdown]
# ### Crear una instancia del clasificador
#
# Es importante haber instalado el paquete del parseador dentro del entorno virtual:
# ```
# python -m spacy download es_core_news_md
# ```

# %%
clasificador = ct.ClasificadorTfIdf(
    fichero_salida=fichero_clasificacion,
    f_compilacion=fichero_compilacion,
    f_particion=fichero_particion,
    temas=('Politica', 'Deportes', 'Salud'),
    d_docs=dir_documentos,
)

# %% [markdown]
# ### Compilar el modelo para la partición actual (generación de vectores tf-idf). Solo hace falta ejecutarlo una vez

# %%
clasificador.compilar()

# %% [markdown]
# ### Probar el modelo sobre la el conjunto de test actual

# %%
clasificador.test()
# Out:
# {'errores': [{'real': 'Deportes/text42.txt', 'pred': 'Salud/text42.txt'},
#   {'real': 'Politica/text32.txt', 'pred': 'Salud/text32.txt'},
#   {'real': 'Salud/text23.txt', 'pred': 'Deportes/text23.txt'}],
#  'predicciones': {'../Datos/Deportes/text17.txt': [('Deportes',
#     0.22609791583220654),
#    ('Politica', 0.08074438525038288),
#    ('Salud', 0.05103969365660253)],
#   '../Datos/Deportes/text32.txt': [('Deportes', 0.25197062875327275),
#    ('Politica', 0.0617521755572689),
#    ('Salud', 0.036785040125896354)],
#   '../Datos/Deportes/text28.txt': [('Deportes', 0.13440339332833195),
#    ('Politica', 0.05400275255067764),
#    ('Salud', 0.023832174947727106)],
#   '../Datos/Deportes/text47.txt': [('Deportes', 0.145200958801964),
#    ('Politica', 0.04595288881257274),
#    ('Salud', 0.04446615093469849)],
#   '../Datos/Deportes/text22.txt': [('Deportes', 0.0781256530841866),
#    ('Politica', 0.06162540697545248),
#    ('Salud', 0.060015426671406254)],
#   '../Datos/Deportes/text23.txt': [('Deportes', 0.15800150256524095),
#    ('Politica', 0.07123016566671292),
#    ('Salud', 0.027296777732923706)],
#   '../Datos/Deportes/text13.txt': [('Deportes', 0.2378227330581016),
#    ('Politica', 0.059703536448002116),
#    ('Salud', 0.04502067523405283)],
#   '../Datos/Deportes/text41.txt': [('Deportes', 0.2099206830448144),
#    ('Politica', 0.04180429520999772),
#    ('Salud', 0.027844186882677983)],
#   '../Datos/Deportes/text36.txt': [('Deportes', 0.26665143394183405),
#    ('Politica', 0.03483402258500709),
#    ('Salud', 0.020106317808591765)],
#   '../Datos/Deportes/text42.txt': [('Salud', 0.13386796949757235),
#    ('Deportes', 0.123643254540317),
#    ('Politica', 0.06845122489135474)],
#   '../Datos/Deportes/text46.txt': [('Deportes', 0.13813421352248362),
#    ('Politica', 0.0389078544153048),
#    ('Salud', 0.036485047228379835)],
#   '../Datos/Deportes/text60.txt': [('Deportes', 0.18206057822523888),
#    ('Politica', 0.07628081867763423),
#    ('Salud', 0.06087315639381049)],
#   '../Datos/Deportes/text20.txt': [('Deportes', 0.21684988429250526),
#    ('Salud', 0.06551362267261887),
#    ('Politica', 0.06364136804441936)],
#   '../Datos/Deportes/text37.txt': [('Deportes', 0.216204303661649),
#    ('Politica', 0.05244804943051642),
#    ('Salud', 0.03085774552637221)],
#   '../Datos/Deportes/text2.txt': [('Deportes', 0.150831397382),
#    ('Politica', 0.06444259492627756),
#    ('Salud', 0.06304060083035448)],
#   '../Datos/Deportes/text21.txt': [('Deportes', 0.2474049770965399),
#    ('Politica', 0.060113665333934294),
#    ('Salud', 0.020547357154114723)],
#   '../Datos/Deportes/text6.txt': [('Deportes', 0.2255474341976861),
#    ('Salud', 0.05762567752305045),
#    ('Politica', 0.05441876714888374)],
#   '../Datos/Deportes/text45.txt': [('Deportes', 0.19987939313458447),
#    ('Politica', 0.033793627139516065),
#    ('Salud', 0.03376195722787251)],
#   '../Datos/Deportes/text19.txt': [('Deportes', 0.30141296844034726),
#    ('Politica', 0.06824375352780136),
#    ('Salud', 0.05678430370888709)],
#   '../Datos/Deportes/text30.txt': [('Deportes', 0.19034238351950072),
#    ('Politica', 0.05683860770924688),
#    ('Salud', 0.04988409742000949)],
#   '../Datos/Deportes/text53.txt': [('Deportes', 0.18881134955797998),
#    ('Salud', 0.038834872174343824),
#    ('Politica', 0.03786931631008918)],
#   '../Datos/Deportes/text12.txt': [('Deportes', 0.2884697465245403),
#    ('Salud', 0.060921890108831804),
#    ('Politica', 0.04148056292992211)],
#   '../Datos/Deportes/text5.txt': [('Deportes', 0.1403491535000705),
#    ('Politica', 0.043077895845837655),
#    ('Salud', 0.04012195200940348)],
#   '../Datos/Deportes/text40.txt': [('Deportes', 0.303799713518851),
#    ('Politica', 0.04602340800313909),
#    ('Salud', 0.03103682431645917)],
#   '../Datos/Deportes/text56.txt': [('Deportes', 0.2015362011894845),
#    ('Salud', 0.048785196162926724),
#    ('Politica', 0.04071939897658312)],
#   '../Datos/Deportes/text9.txt': [('Deportes', 0.2618719772982458),
#    ('Politica', 0.05990115999289005),
#    ('Salud', 0.05346896322485079)],
#   '../Datos/Deportes/text16.txt': [('Deportes', 0.2602409883683213),
#    ('Politica', 0.034708012420645036),
#    ('Salud', 0.03443386091612788)],
#   '../Datos/Deportes/text34.txt': [('Deportes', 0.2546603918681704),
#    ('Politica', 0.04765545382275105),
#    ('Salud', 0.03205585998006979)],
#   '../Datos/Deportes/text38.txt': [('Deportes', 0.23150836344478337),
#    ('Politica', 0.036433754226181794),
#    ('Salud', 0.031528739080582714)],
#   '../Datos/Deportes/text26.txt': [('Deportes', 0.23815883727429468),
#    ('Politica', 0.04963501722019293),
#    ('Salud', 0.03532884090451628)],
#   '../Datos/Politica/text24.txt': [('Politica', 0.2124092144981347),
#    ('Deportes', 0.061242517709116547),
#    ('Salud', 0.03814029769048412)],
#   '../Datos/Politica/text21.txt': [('Politica', 0.1522136555185148),
#    ('Deportes', 0.06989277790454165),
#    ('Salud', 0.06900823011848184)],
#   '../Datos/Politica/text52.txt': [('Politica', 0.18337492911936681),
#    ('Salud', 0.09096961507968651),
#    ('Deportes', 0.05385316074045073)],
#   '../Datos/Politica/text4.txt': [('Politica', 0.09449755788672419),
#    ('Salud', 0.08556680470761287),
#    ('Deportes', 0.03912509887199242)],
#   '../Datos/Politica/text53.txt': [('Politica', 0.12262626421790589),
#    ('Salud', 0.11148153743750909),
#    ('Deportes', 0.06657486898037772)],
#   '../Datos/Politica/text26.txt': [('Politica', 0.2816948550949049),
#    ('Deportes', 0.06637988567110403),
#    ('Salud', 0.06294185842833337)],
#   '../Datos/Politica/text15.txt': [('Politica', 0.15858397855480938),
#    ('Salud', 0.08013231254660226),
#    ('Deportes', 0.054148231782915945)],
#   '../Datos/Politica/text14.txt': [('Politica', 0.28171094295471755),
#    ('Salud', 0.05684012329443901),
#    ('Deportes', 0.053345188640461255)],
#   '../Datos/Politica/text20.txt': [('Politica', 0.20828630199606907),
#    ('Salud', 0.10913416468584959),
#    ('Deportes', 0.05276882071412172)],
#   '../Datos/Politica/text23.txt': [('Politica', 0.24135142778375432),
#    ('Salud', 0.07388927493984015),
#    ('Deportes', 0.05672321385149581)],
#   '../Datos/Politica/text27.txt': [('Politica', 0.1936992668844434),
#    ('Salud', 0.05028057641989478),
#    ('Deportes', 0.04915379470260788)],
#   '../Datos/Politica/text12.txt': [('Politica', 0.2068150397803234),
#    ('Salud', 0.08121444162859741),
#    ('Deportes', 0.0491368841402564)],
#   '../Datos/Politica/text2.txt': [('Politica', 0.1735771559278046),
#    ('Salud', 0.10415608196840462),
#    ('Deportes', 0.06955951779284247)],
#   '../Datos/Politica/text17.txt': [('Politica', 0.169152307559132),
#    ('Salud', 0.05643489884153859),
#    ('Deportes', 0.042187152425671386)],
#   '../Datos/Politica/text28.txt': [('Politica', 0.11104011265245531),
#    ('Salud', 0.0462585983568401),
#    ('Deportes', 0.03327142768703226)],
#   '../Datos/Politica/text34.txt': [('Politica', 0.17970759502909367),
#    ('Salud', 0.09257723361038794),
#    ('Deportes', 0.03237014691270299)],
#   '../Datos/Politica/text16.txt': [('Politica', 0.2561602651508649),
#    ('Salud', 0.06566186693207351),
#    ('Deportes', 0.042593712375503495)],
#   '../Datos/Politica/text60.txt': [('Politica', 0.12728947328184645),
#    ('Salud', 0.037479963261949065),
#    ('Deportes', 0.02742785573831584)],
#   '../Datos/Politica/text9.txt': [('Politica', 0.19046536289161126),
#    ('Deportes', 0.07662356659336796),
#    ('Salud', 0.05945826860086209)],
#   '../Datos/Politica/text31.txt': [('Politica', 0.2306694774709058),
#    ('Salud', 0.11178300416783822),
#    ('Deportes', 0.06483801077015425)],
#   '../Datos/Politica/text33.txt': [('Politica', 0.23900364191886436),
#    ('Deportes', 0.027986325094456272),
#    ('Salud', 0.02533402065678313)],
#   '../Datos/Politica/text43.txt': [('Politica', 0.15344020911825962),
#    ('Salud', 0.054517377400594536),
#    ('Deportes', 0.04647695802015717)],
#   '../Datos/Politica/text6.txt': [('Politica', 0.2631850684674361),
#    ('Salud', 0.08481193576698358),
#    ('Deportes', 0.03906271626610876)],
#   '../Datos/Politica/text58.txt': [('Politica', 0.20069722046286267),
#    ('Salud', 0.09733109097843085),
#    ('Deportes', 0.04121694802646513)],
#   '../Datos/Politica/text50.txt': [('Politica', 0.15813426292530355),
#    ('Salud', 0.09134877756698875),
#    ('Deportes', 0.0731443664337424)],
#   '../Datos/Politica/text55.txt': [('Politica', 0.0867810678693706),
#    ('Deportes', 0.051386238923228376),
#    ('Salud', 0.04637963987054703)],
#   '../Datos/Politica/text32.txt': [('Salud', 0.07654520267083909),
#    ('Politica', 0.06701321654186045),
#    ('Deportes', 0.02928991354239224)],
#   '../Datos/Politica/text40.txt': [('Politica', 0.2568164410652677),
#    ('Salud', 0.04224539941466733),
#    ('Deportes', 0.037275374735209255)],
#   '../Datos/Politica/text59.txt': [('Politica', 0.16781876056136516),
#    ('Salud', 0.06699152752890483),
#    ('Deportes', 0.02956835978768861)],
#   '../Datos/Politica/text18.txt': [('Politica', 0.21103519751524547),
#    ('Salud', 0.0995714614438703),
#    ('Deportes', 0.09763672771375713)],
#   '../Datos/Salud/text50.txt': [('Salud', 0.2426520511824865),
#    ('Politica', 0.10768527216382359),
#    ('Deportes', 0.07713642704127853)],
#   '../Datos/Salud/text44.txt': [('Salud', 0.11590505450148195),
#    ('Deportes', 0.033034728787185705),
#    ('Politica', 0.0217500062783209)],
#   '../Datos/Salud/text52.txt': [('Salud', 0.24925200525735056),
#    ('Politica', 0.08768912092827215),
#    ('Deportes', 0.0642251378118261)],
#   '../Datos/Salud/text40.txt': [('Salud', 0.36123473062330774),
#    ('Politica', 0.06490050930578006),
#    ('Deportes', 0.046180596884498805)],
#   '../Datos/Salud/text42.txt': [('Salud', 0.29944150982704104),
#    ('Politica', 0.109359032556454),
#    ('Deportes', 0.059619709036913354)],
#   '../Datos/Salud/text31.txt': [('Salud', 0.22045015000136126),
#    ('Politica', 0.09731951512760481),
#    ('Deportes', 0.06997364834904733)],
#   '../Datos/Salud/text6.txt': [('Salud', 0.22801772559146138),
#    ('Politica', 0.11785334320215594),
#    ('Deportes', 0.05578218696407216)],
#   '../Datos/Salud/text46.txt': [('Salud', 0.39647851859535),
#    ('Politica', 0.04347044490448297),
#    ('Deportes', 0.02383813912753446)],
#   '../Datos/Salud/text30.txt': [('Salud', 0.20575681389067724),
#    ('Politica', 0.0844357353687768),
#    ('Deportes', 0.060044681159017094)],
#   '../Datos/Salud/text27.txt': [('Salud', 0.20912098136560506),
#    ('Politica', 0.12353305232056148),
#    ('Deportes', 0.03225403623379931)],
#   '../Datos/Salud/text35.txt': [('Salud', 0.2555066250974654),
#    ('Politica', 0.0817355971441498),
#    ('Deportes', 0.03321450308506942)],
#   '../Datos/Salud/text49.txt': [('Salud', 0.1987940043875531),
#    ('Politica', 0.08934566050920466),
#    ('Deportes', 0.06864574132884435)],
#   '../Datos/Salud/text22.txt': [('Salud', 0.18114271178093652),
#    ('Politica', 0.0926688218774633),
#    ('Deportes', 0.028713528336824733)],
#   '../Datos/Salud/text13.txt': [('Salud', 0.3100893208469428),
#    ('Politica', 0.11720567073933309),
#    ('Deportes', 0.07142115082205722)],
#   '../Datos/Salud/text2.txt': [('Salud', 0.22875345573545358),
#    ('Politica', 0.09220222417418181),
#    ('Deportes', 0.05283317863528498)],
#   '../Datos/Salud/text55.txt': [('Salud', 0.27627874766049865),
#    ('Politica', 0.10023824258447682),
#    ('Deportes', 0.04611618241834445)],
#   '../Datos/Salud/text3.txt': [('Salud', 0.13695385663975174),
#    ('Politica', 0.08685262338427038),
#    ('Deportes', 0.037289860274107474)],
#   '../Datos/Salud/text34.txt': [('Salud', 0.3455036324396147),
#    ('Politica', 0.0651744088613868),
#    ('Deportes', 0.025381981896892718)],
#   '../Datos/Salud/text45.txt': [('Salud', 0.2920066811497978),
#    ('Deportes', 0.03944089965025173),
#    ('Politica', 0.03547848939634028)],
#   '../Datos/Salud/text43.txt': [('Salud', 0.26976342178759233),
#    ('Politica', 0.08476200549114385),
#    ('Deportes', 0.04510050375451092)],
#   '../Datos/Salud/text41.txt': [('Salud', 0.3069040576920957),
#    ('Deportes', 0.032022810005139686),
#    ('Politica', 0.028951071638430057)],
#   '../Datos/Salud/text5.txt': [('Salud', 0.15847278696714862),
#    ('Politica', 0.09066326488488081),
#    ('Deportes', 0.04972481459444607)],
#   '../Datos/Salud/text47.txt': [('Salud', 0.15264900472117088),
#    ('Deportes', 0.09788768783325992),
#    ('Politica', 0.052942653805004014)],
#   '../Datos/Salud/text60.txt': [('Salud', 0.16107989367933792),
#    ('Politica', 0.10159868962808563),
#    ('Deportes', 0.07278093586903062)],
#   '../Datos/Salud/text25.txt': [('Salud', 0.3888737492894435),
#    ('Politica', 0.07781926459415799),
#    ('Deportes', 0.02910522995607036)],
#   '../Datos/Salud/text16.txt': [('Salud', 0.3684586081261987),
#    ('Politica', 0.06603462022108353),
#    ('Deportes', 0.02381435535142954)],
#   '../Datos/Salud/text33.txt': [('Salud', 0.14839102885484337),
#    ('Politica', 0.04920693143717764),
#    ('Deportes', 0.016518293698719065)],
#   '../Datos/Salud/text29.txt': [('Salud', 0.10376333954795437),
#    ('Politica', 0.05175847199001909),
#    ('Deportes', 0.04085541403332405)],
#   '../Datos/Salud/text23.txt': [('Deportes', 0.15091335504943768),
#    ('Politica', 0.12768707425835382),
#    ('Salud', 0.1046475951801103)],
#   '../Datos/Salud/text57.txt': [('Salud', 0.15275370762374096),
#    ('Politica', 0.07650877391777047),
#    ('Deportes', 0.059663234862770864)]},
#  'tasa_aciertos': '96.66666666666667%'}

# %% [markdown]
# ### Probar funcionalidad de clasificar documentos sin etiquetar (aunque en este caso sabemos que es de deportes)

# %%
paths = [
    'texto_prueba_concepto.txt'
]
clasificador.clasifica(paths, exportar=False)
# Out:
# {'texto_prueba_concepto.txt': [('Deportes', 0.10392268630637337),
#   ('Politica', 0.011241229986113075),
#   ('Salud', 0.0029481742415920034)]}
